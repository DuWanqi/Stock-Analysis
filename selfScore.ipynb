# %%
from pathlib import Path
import json
import os
import requests
from time import sleep

# def start_session(email,password):
#     s = requests>Session()
#     s.auth = (email,password)
#     r = s.post('https://api.worldquantbrain.com/authentication')
def start_session(username, password):
    s = requests.Session()
    s.auth = (username, password)

    while True:
        try:
            # Send a POST request to the /authentication API
            response = s.post('https://api.worldquantbrain.com/authentication')
            response.raise_for_status()  # Raises an HTTPError if the status is 4xx, 5xx
            break
        except Exception as e:
            print(f"Connection down, trying to login again: {e}")
            sleep(10)

    print(response)
    return s

# %%
username = "wanqidu@link.cuhk.edu.cn"
password = "worldquant159753"

s = start_session(username, password)
# Out:
# <Response [201]>

# %% [markdown]
# Simulating an Alpha

# %%
simulation_data = {
    'type': 'REGULAR',
    'settings': {
        'instrumentType': 'EQUITY',
        'region': 'CHN',
        'universe': 'TOP3000',
        'delay': 1,
        'decay': 5,
        'neutralization': 'SECTOR',
        'truncation': 0.08,
        'pasteurization': 'ON',
        'unitHandling': 'VERIFY',
        'nanHandling': 'ON',
        'language': 'FASTEXPR',
        'visualization': False,
    },
    'regular': 'high-close'
}
simulation_response = s.post('https://api.worldquantbrain.com/simulations', json=simulation_data)

# %% [markdown]
# Alpha 回测状态和结果检索

# %%
from time import sleep

simulation_progress_url = simulation_response.headers['Location']
finished = False
while True:
    simulation_progress = s.get(simulation_progress_url)
    if simulation_progress.headers.get("Retry-After", 0) == 0:
        break
    print("Sleeping for " + simulation_progress.headers["Retry-After"] + " seconds")
    sleep(float(simulation_progress.headers["Retry-After"]))
print("Alpha done simulating, getting alpha details")
alpha_id = simulation_progress.json()["alpha"]
alpha = s.get("https://api.worldquantbrain.com/alphas/" + alpha_id)
alpha.json()
# Out:
# Sleeping for 2.5 seconds
# Sleeping for 2.5 seconds
# Sleeping for 2.5 seconds
# Sleeping for 2.5 seconds
# Alpha done simulating, getting alpha details
# {'id': 'gxEQRQg',
#  'type': 'REGULAR',
#  'author': 'WD77850',
#  'settings': {'instrumentType': 'EQUITY',
#   'region': 'CHN',
#   'universe': 'TOP3000',
#   'delay': 1,
#   'decay': 5,
#   'neutralization': 'SECTOR',
#   'truncation': 0.08,
#   'pasteurization': 'ON',
#   'unitHandling': 'VERIFY',
#   'nanHandling': 'ON',
#   'language': 'FASTEXPR',
#   'visualization': False},
#  'regular': {'code': 'high-close', 'description': None, 'operatorCount': 1},
#  'dateCreated': '2024-01-29T22:45:54-05:00',
#  'dateSubmitted': None,
#  'dateModified': '2024-01-30T22:00:01-05:00',
#  'name': None,
#  'favorite': False,
#  'hidden': False,
#  'color': 'RED',
#  'category': None,
#  'tags': [],
#  'grade': None,
#  'stage': 'IS',
#  'status': 'UNSUBMITTED',
#  'is': {'pnl': 2384664,
#   'bookSize': 20000000,
#   'longCount': 855,
#   'shortCount': 1871,
#   'turnover': 0.2494,
#   'returns': 0.0247,
#   'drawdown': 0.6577,
#   'margin': 0.000198,
#   'fitness': 0.05,
#   'sharpe': 0.15,
#   'startDate': '2012-01-22',
#   'checks': [{'name': 'LOW_SHARPE',
#     'result': 'FAIL',
#     'limit': 2.07,
#     'value': 0.15},
#    {'name': 'LOW_FITNESS', 'result': 'FAIL', 'limit': 1.0, 'value': 0.05},
#    {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.2494},
#    {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.2494},
#    {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#    {'name': 'LOW_RETURNS', 'result': 'FAIL', 'limit': 0.08, 'value': 0.0247},
#    {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#     'result': 'PASS',
#     'limit': 0.09,
#     'value': 0.4},
#    {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#     'result': 'PASS',
#     'ratio': 0.4,
#     'limit': 0.06,
#     'value': 0.61},
#    {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#     'result': 'PASS',
#     'ratio': 0.4,
#     'limit': 0.0099,
#     'value': 0.0932},
#    {'name': 'SELF_CORRELATION', 'result': 'PENDING'},
#    {'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#    {'name': 'REGULAR_SUBMISSION', 'result': 'PENDING'},
#    {'name': 'MATCHES_THEMES',
#     'result': 'WARNING',
#     'matched': [],
#     'unmatched': [{'id': '8BLze4d',
#       'name': 'Utilities sector Theme',
#       'multiplier': 3.0},
#      {'id': 'kyWzP4K', 'name': 'Data Set Theme 4', 'multiplier': 2.5}]},
#    {'name': 'MATCHES_COMPETITION',
#     'result': 'WARNING',
#     'matched': [],
#     'unmatched': [{'id': 'SAC2024M1',
#       'name': 'SuperAlpha Competition 2024 Month 1'}]},
#    {'name': 'IS_LADDER_SHARPE',
#     'result': 'FAIL',
#     'year': 2,
#     'startDate': '2022-01-24',
#     'endDate': '2020-01-25',
#     'limit': 2.07,
#     'value': 0.22}]},
#  'os': None,
#  'train': None,
#  'test': None,
#  'prod': None,
#  'competitions': None,
#  'themes': None,
#  'team': None}

# %% [markdown]
# Record Sets of Alpha Simulations Alpha Pnl

# %%
from time import sleep


finished = False
while True:
    pnl  = s.get("https://api.worldquantbrain.com/alphas/"+ alpha_id+"/recordsets/pnl")
    if pnl.headers.get("Retry-After", 0) == 0:
        break
    print("Sleeping for " + pnl.headers["Retry-After"] + " seconds")
    sleep(float(pnl.headers["Retry-After"]))
print("PnL retrieved")
pnl.json()
# Out:
# Sleeping for 1.0 seconds
# PnL retrieved
# {'schema': {'name': 'pnl',
#   'title': 'PnL',
#   'properties': [{'name': 'date', 'title': 'Date', 'type': 'date'},
#    {'name': 'pnl', 'title': 'PnL', 'type': 'amount'}]},
#  'records': [['2012-01-30', 14520.0],
#   ['2012-01-31', 5831.0],
#   ['2012-02-01', 27758.0],
#   ['2012-02-02', 44082.0],
#   ['2012-02-03', 23661.0],
#   ['2012-02-06', 29201.0],
#   ['2012-02-07', 62846.0],
#   ['2012-02-08', 109677.0],
#   ['2012-02-09', 106651.0],
#   ['2012-02-10', 111026.0],
#   ['2012-02-13', 167111.0],
#   ['2012-02-14', 140780.0],
#   ['2012-02-15', 70805.0],
#   ['2012-02-16', 7592.0],
#   ['2012-02-17', 41661.0],
#   ['2012-02-20', 83715.0],
#   ['2012-02-21', 164066.0],
#   ['2012-02-22', 233108.0],
#   ['2012-02-23', 253428.0],
#   ['2012-02-24', 219408.0],
#   ['2012-02-27', 249584.0],
#   ['2012-02-28', 223027.0],
#   ['2012-02-29', 222742.0],
#   ['2012-03-01', 225368.0],
#   ['2012-03-02', 244541.0],
#   ['2013-07-16', 5216278.0],
#   ['2013-07-17', 5178661.0],
#   ['2013-07-18', 5179833.0],
#   ['2013-07-19', 5187606.0],
#   ['2013-07-22', 5291609.0],
#   ['2013-07-23', 5344741.0],
#   ['2013-07-24', 5426663.0],
#   ['2013-07-25', 5214792.0],
#   ['2013-07-26', 5194576.0],
#   ['2013-07-29', 5130736.0],
#   ['2013-07-30', 4964990.0],
#   ['2013-07-31', 4982037.0],
#   ['2013-08-01', 5166431.0],
#   ['2013-08-02', 5137133.0],
#   ['2013-08-05', 5155443.0],
#   ['2013-08-06', 5176626.0],
#   ['2013-08-07', 5040525.0],
#   ['2013-08-08', 5066814.0],
#   ['2013-08-09', 4982842.0],
#   ['2013-08-12', 4826472.0],
#   ['2013-08-13', 4818919.0],
#   ['2013-08-14', 4872712.0],
#   ['2013-08-15', 4851605.0],
#   ['2013-08-16', 4754198.0],
#   ['2013-08-19', 4851950.0],
#   ['2013-08-20', 4865489.0],
#   ['2013-08-21', 4789328.0],
#   ['2013-08-22', 4865907.0],
#   ['2013-08-23', 4989400.0],
#   ['2013-08-26', 4966356.0],
#   ['2013-08-27', 4970851.0],
#   ['2013-08-28', 4846689.0],
#   ['2013-08-29', 4768598.0],
#   ['2013-08-30', 4493755.0],
#   ['2013-09-02', 4590082.0],
#   ['2013-09-03', 4687192.0],
#   ['2013-09-04', 4693062.0],
#   ['2013-09-05', 4803400.0],
#   ['2013-09-06', 4841325.0],
#   ['2013-09-09', 4720997.0],
#   ['2013-09-10', 4572321.0],
#   ['2013-09-11', 4325688.0],
#   ['2013-09-12', 4257285.0],
#   ['2013-09-13', 4450225.0],
#   ['2013-09-16', 4589399.0],
#   ['2013-09-17', 4627073.0],
#   ['2013-09-18', 4643432.0],
#   ['2013-09-23', 4753137.0],
#   ['2013-09-24', 4800623.0],
#   ['2013-09-25', 4764080.0],
#   ['2013-09-26', 4756004.0],
#   ['2013-09-27', 4825585.0],
#   ['2013-09-30', 4997914.0],
#   ['2013-10-08', 4951747.0],
#   ['2013-10-09', 4984333.0],
#   ['2013-10-10', 4806207.0],
#   ['2013-10-11', 4723658.0],
#   ['2013-10-14', 4713680.0],
#   ['2013-10-15', 4640627.0],
#   ['2013-10-16', 4495294.0],
#   ['2013-10-17', 4395542.0],
#   ['2013-10-18', 4475219.0],
#   ['2013-10-21', 4628182.0],
#   ['2013-10-22', 4372702.0],
#   ['2013-10-23', 4332909.0],
#   ['2013-10-24', 4313036.0],
#   ['2013-10-25', 4274302.0],
#   ['2013-10-28', 4361326.0],
#   ['2013-10-29', 4433963.0],
#   ['2013-10-30', 4450871.0],
#   ['2013-10-31', 4277443.0],
#   ['2013-11-01', 4266702.0],
#   ['2013-11-04', 4277206.0],
#   ['2013-11-05', 4436075.0],
#   ['2013-11-06', 4381935.0],
#   ['2013-11-07', 4376939.0],
#   ['2013-11-08', 4391263.0],
#   ['2013-11-11', 4419513.0],
#   ['2013-11-12', 4417172.0],
#   ['2013-11-13', 4465925.0],
#   ['2013-11-14', 4587108.0],
#   ['2013-11-15', 4627971.0],
    if competition is not None:
        part_url = f'competitions/{competition}'
    elif team_id is not None:
        part_url = f'teams/{team_id}'
    else:
        part_url = 'users/self'
    while True:
        result = s.get(
            f"https://api.worldquantbrain.com/{part_url}/alphas/" + alpha_id + "/before-and-after-performance"
        )
        if "retry-after" in result.headers:
            time.sleep(float(result.headers["Retry-After"]))
        else:
            break
    if result.json().get("stats", 0) == 0:
        return {}
    if result.status_code != 200:
        return {}

    return result.json()

# %%
new_pc = performance_comparison(s, alpha_id)

# %%
new_pc
# Out:
# {'stats': {'before': {'bookSize': 20000000,
#    'pnl': 12312064.0,
#    'longCount': 1067,
#    'shortCount': 979,
#    'drawdown': 0.1105,
#    'turnover': 0.1807,
#    'returns': 0.1294,
#    'margin': 0.001432,
#    'sharpe': 4.42,
#    'fitness': 3.74},
#   'after': {'bookSize': 20000000,
#    'pnl': 8698288.0,
#    'longCount': 1023,
#    'shortCount': 1160,
#    'drawdown': 0.3181,
#    'turnover': 0.188,
#    'returns': 0.0834,
#    'margin': 0.000887,
#    'sharpe': 1.04,
#    'fitness': 0.69}},
#  'yearlyStats': {'before': {'schema': {'name': 'yearly-stats',
#     'title': 'Yearly Stats',
#     'properties': [{'name': 'year', 'title': 'Year', 'type': 'year'},
#      {'name': 'pnl', 'title': 'PnL', 'type': 'amount'},
#      {'name': 'bookSize', 'title': 'Book Size', 'type': 'amount'},
#      {'name': 'longCount', 'title': 'Long Count', 'type': 'integer'},
#      {'name': 'shortCount', 'title': 'Short Count', 'type': 'integer'},
#      {'name': 'turnover', 'title': 'Turnover', 'type': 'percent'},
#      {'name': 'sharpe', 'title': 'Sharpe', 'type': 'decimal'},
#      {'name': 'returns', 'title': 'Returns', 'type': 'percent'},
#      {'name': 'drawdown', 'title': 'Drawdown', 'type': 'percent'},
#      {'name': 'margin', 'title': 'Margin', 'type': 'permyriad'},
#      {'name': 'fitness', 'title': 'Fitness', 'type': 'decimal'},
#      {'name': 'stage', 'title': 'Stage', 'type': 'string'}]},
#    'records': [['2011',
#      1357172.0,
#      20000000,
#      921,
#      869,
#      0.1988,
#      9.24,
#      0.1844,
#      0.0043,
#      0.001856,
#      8.9,
#      'IS'],
#     ['2012',
#      1610922.0,
#      20000000,
#      985,
#      921,
#      0.1903,
#      8.32,
#      0.1657,
#      0.0067,
#      0.001742,
#      7.76,
#      'IS'],
#     ['2013',
#      1492770.0,
#      20000000,
#      1029,
#      957,
#      0.1848,
#      5.6,
#      0.1568,
#      0.017,
#      0.001697,
#      5.16,
#      'IS'],
#     ['2014',
#      1344713.0,
#      20000000,
#      1017,
#      919,
#      0.1849,
#      6.39,
#      0.1372,
#      0.0173,
#      0.001484,
#      5.5,
#      'IS'],
#     ['2015',
#      135924.0,
#      20000000,
#      1023,
#      826,
#      0.1734,
#      0.26,
#      0.0139,
#      0.1105,
#      0.000161,
#      0.07,
#      'IS'],
#     ['2016',
#      1030317.0,
#      20000000,
#      1066,
#      927,
#      0.1808,
#      4.08,
#      0.1056,
#      0.0169,
#      0.001168,
#      3.12,
#      'IS'],
#     ['2017',
#      1561776.0,
#      20000000,
#      1161,
#      1072,
#      0.1758,
#      7.92,
#      0.16,
#      0.0061,
#      0.00182,
#      7.56,
#      'IS'],
#     ['2018',
#      1089003.0,
#      20000000,
#      1143,
#      1061,
#      0.1718,
#      4.22,
#      0.112,
#      0.0154,
#      0.001305,
#      3.41,
#      'IS'],
#     ['2019',
#      1206868.0,
#      20000000,
#      1130,
#      1091,
#      0.1776,
#      5.85,
#      0.1237,
#      0.0078,
#      0.001392,
#      4.88,
#      'IS'],
#     ['2020',
#      1003922.0,
#      20000000,
#      1156,
#      1113,
#      0.1751,
#      3.11,
#      0.1136,
#      0.0192,
#      0.001297,
#      2.5,
#      'IS'],
#     ['2021',
#      478676.0,
#      20000000,
#      1178,
#      1156,
#      0.1639,
#      12.17,
#      0.4127,
#      0.0056,
#      0.005037,
#      19.31,
#      'IS']]},
#   'after': {'schema': {'name': 'yearly-stats',
#     'title': 'Yearly Stats',
#     'properties': [{'name': 'year', 'title': 'Year', 'type': 'year'},
#      {'name': 'pnl', 'title': 'PnL', 'type': 'amount'},
#      {'name': 'bookSize', 'title': 'Book Size', 'type': 'amount'},
#      {'name': 'longCount', 'title': 'Long Count', 'type': 'integer'},
#      {'name': 'shortCount', 'title': 'Short Count', 'type': 'integer'},
#      {'name': 'turnover', 'title': 'Turnover', 'type': 'percent'},
#      {'name': 'sharpe', 'title': 'Sharpe', 'type': 'decimal'},
#      {'name': 'returns', 'title': 'Returns', 'type': 'percent'},
#      {'name': 'drawdown', 'title': 'Drawdown', 'type': 'percent'},
#      {'name': 'margin', 'title': 'Margin', 'type': 'permyriad'},
#      {'name': 'fitness', 'title': 'Fitness', 'type': 'decimal'},
#      {'name': 'stage', 'title': 'Stage', 'type': 'string'}]},
#    'records': [['2011',
#      1357172.0,
#      20000000,
#      921,
#      869,
#      0.1988,
#      9.24,
#      0.1844,
#      0.0043,
#      0.001856,
#      8.9,
#      'IS'],
#     ['2012',
#      1659171.0,
#      20000000,
#      971,
#      972,
#      0.2016,
#      8.49,
#      0.1707,
#      0.0075,
#      0.001693,
#      7.81,
#      'IS'],
#     ['2013',
#      1648395.0,
#      20000000,
#      1008,
#      1018,
#      0.194,
#      5.26,
#      0.1732,
#      0.0215,
#      0.001785,
#      4.97,
#      'IS'],
#     ['2014',
#      1169519.0,
#      20000000,
#      1000,
#      982,
#      0.1946,
#      4.77,
#      0.1193,
#      0.0193,
#      0.001227,
#      3.73,
#      'IS'],
#     ['2015',
#      -90145.0,
#      20000000,
#      1008,
#      901,
#      0.1822,
#      -0.18,
#      -0.0092,
#      0.1408,
#      -0.000101,
#      -0.04,
#      'IS'],
#     ['2016',
#      900673.0,
#      20000000,
#      1048,
#      1008,
#      0.1856,
#      3.28,
#      0.0923,
#      0.0184,
#      0.000995,
#      2.31,
#      'IS'],
#     ['2017',
#      1359251.0,
#      20000000,
#      1140,
#      1161,
#      0.1829,
#      5.91,
#      0.1393,
#      0.0075,
#      0.001523,
#      5.16,
#      'IS'],
#     ['2018',
#      987392.0,
#      20000000,
#      1125,
#      1153,
#      0.178,
#      3.2,
#      0.1016,
#      0.0202,
#      0.001141,
#      2.42,
#      'IS'],
#     ['2019',
#      1022167.0,
#      20000000,
#      1108,
#      1184,
#      0.1831,
#      4.49,
#      0.1047,
#      0.0133,
#      0.001144,
#      3.4,
#      'IS'],
#     ['2020',
#      1255522.0,
#      20000000,
#      1125,
#      1213,
#      0.1779,
#      3.32,
#      0.142,
#      0.0249,
#      0.001597,
#      2.97,
#      'IS'],
#     ['2021',
#      -1621989.0,
#      20000000,
#      794,
#      2173,
#      0.1911,
#      -0.71,
#      -0.1669,
#      0.2536,
#      -0.001747,
#      -0.66,
#      'IS'],
#     ['2022',
#      -948838.0,
#      20000000,
#      778,
#      2279,
#      0.1993,
#      -6.82,
#      -1.6944,
#      0.0539,
#      -0.017004,
#      -19.89,
#      'IS']]}},
#  'pnl': {'schema': {'name': 'beforeAndAfterPnN',
#    'title': 'PnL Before And After Submission',
#    'properties': [{'name': 'date', 'title': 'Date', 'type': 'date'},
#     {'name': 'beforePnL', 'title': 'PnL Before Submission', 'type': 'amount'},
#     {'name': 'afterPnL', 'title': 'PnL After Submission', 'type': 'amount'}]},
#   'records': [['2011-04-07', 932.0, 932.0],
#    ['2011-04-08', 10958.0, 10958.0],
#    ['2011-04-11', -3933.0, -3933.0],
#    ['2011-04-12', 5013.0, 5013.0],
#    ['2011-04-13', 18145.0, 18145.0],
#    ['2011-04-14', 18469.0, 18469.0],
#    ['2011-04-15', 24153.0, 24153.0],
#    ['2011-04-18', 17603.0, 17603.0],
#    ['2011-04-19', 31839.0, 31839.0],
#    ['2011-04-20', 59303.0, 59303.0],
#    ['2011-04-21', 75543.0, 75543.0],
#    ['2011-04-22', 87159.0, 87159.0],
#    ['2011-04-25', 101568.0, 101568.0],
#    ['2011-04-26', 109551.0, 109551.0],
#    ['2011-04-27', 93212.0, 93212.0],
#    ['2011-04-28', 113522.0, 113522.0],
#    ['2011-04-29', 113507.0, 113507.0],
#    ['2011-05-03', 103006.0, 103006.0],
#    ['2011-05-04', 97039.0, 97039.0],
#    ['2011-05-05', 98662.0, 98662.0],
#    ['2011-05-06', 106616.0, 106616.0],
#    ['2011-05-09', 100377.0, 100377.0],
#    ['2011-05-10', 99880.0, 99880.0],
#    ['2011-05-11', 94657.0, 94657.0],
#    ['2011-05-12', 88443.0, 88443.0],
#    ['2011-05-13', 78994.0, 78994.0],
#    ['2011-05-16', 70886.0, 70886.0],
#    ['2011-05-17', 93256.0, 93256.0],
#    ['2011-05-18', 90426.0, 90426.0],
#    ['2011-05-19', 102866.0, 102866.0],
#    ['2011-05-20', 109010.0, 109010.0],
#    ['2011-05-23', 108631.0, 108631.0],
#    ['2011-05-24', 128932.0, 128932.0],
#    ['2011-05-25', 116701.0, 116701.0],
#    ['2011-05-26', 108810.0, 108810.0],
#    ['2011-05-27', 176909.0, 176909.0],
#    ['2011-05-30', 233093.0, 233093.0],
#    ['2011-05-31', 237358.0, 237358.0],
#    ['2011-06-01', 232356.0, 232356.0],
#    ['2015-05-18', 6019991.0, 6224729.0],
#    ['2015-05-19', 6018441.0, 6208345.0],
#    ...]},
#  'partition': ['settings.instrumentType', 'settings.region', 'settings.delay']}

# %%
# new_records = new_pc["pnl"]["records"] #big list
# before = []
# after = []
# for lis in new_records:
#     before.append(lis[1])
#     after.append(lis[2])
new_records = pc["records"] #big list
before = []
after = []
for lis in new_records:
    before.append(lis[1])

# %% [markdown]
# 参考Fitness的逻辑， 自设一个Filtering Scoring

# %%
before_after_stats = performance_comparison(s, alpha_id)['stats']

# %%
def calculate_score(data):
    returns_drawdown_ratio = min(data['returns']/data['drawdown'],3)

    score = data['sharpe'] = returns_drawdown_ratio / max(data['turnover'],0.125)
    return score

# %%
calculate_score(before_after_stats['before'])
# Out:
# 6.480579546109022

# %%
calculate_score(before_after_stats['after'])
# Out:
# 1.3945835312058967

# %%
def update_alpha_color(session, alpha_id,color):
    update_data = {"color":color}
    response = session.patch(f"https://api.worldquantbrain.com/alphas/{alpha_id}", json=update_data)
    return response.status_code == 200
if calculate_score(before_after_stats['after'])>calculate_score(before_after_stats['before']):
    update_alpha_color(session = s, alpha_id = alpha_id, color = 'GREEN')
else:
    print("The alpha is not avery good")
    update_alpha_color(session = s, alpha_id = alpha_id, color = 'RED')
# Out:
# The alpha is not avery good

# %% [markdown]
# 参考101 performance 的逻辑， 自设一个Filtering Score

# %%
import math
def calculate_score(data,returns,turnover):
    records = data['records']# long list
    drawdown_list = []
    for lis in records:
        drawdown = lis[8]
        drawdown_list.append(drawdown**2)
    new_drawdown = math.sqrt(sum(drawdown_list))
    Burke_ratio = min(returns/new_drawdown,3)

    score = data['sharpe'] = Burke_ratio / max(turnover,0.125)
    return score

# %%
def catch_return_turnover(data):
    returns = data['returns']

    turnover = data['turnover']
    return returns, turnover

# %%
before_after_yearlyStats = performance_comparison(s, alpha_id)['yearlyStats']

# %%
returns1, turnover1 = catch_return_turnover(before_after_stats['before'])
returns2, turnover2 = catch_return_turnover(before_after_stats['after'])

# %%
calculate_score(before_after_yearlyStats['before'],returns1,turnover1)
# Out:
# 5.8416943767194125

# %%
pnl
# Out:
# <Response [200]>

# %% [markdown]
# Alpha List Alpha 列表

# %%
def get_n_is_alphas(session, total_alphas, limit=100):
    fetched_alphas = []
    offset = 0
    #alphaNum = 0#我自己加的

    while len(fetched_alphas) < total_alphas:
        response = session.get(f"https://api.worldquantbrain.com/users/self/alphas?stage=OS&limit={limit}&offset={offset}")
        alphas = response.json()["results"]# 是不是要加上region的限制！
        # if alphas[0]["settings"]["region"] == "CHN":
        #     fetched_alphas.extend(alphas)
        # else:
        #     continue
        fetched_alphas.extend(alphas)
            
        #alphaNum += len(alphas)  # Count the total number of fetched alphas
        

        if len(alphas) < limit:
            break
        offset += limit

    return fetched_alphas[:total_alphas]

sim_result = get_n_is_alphas(s,50)

# %%
sim_result
# Out:
# [{'id': 'Kklq9ql',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'ILLIQUID_MINVOL1M',
#    'delay': 1,
#    'decay': 70,
#    'neutralization': 'INDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': "c = implied_volatility_call_150;\r\np = implied_volatility_put_150;\r\ns = c-p;\r\na = group_extra(s*1.5,0.6,industry);\r\ngroup1 = bucket(ts_rank(ts_std_dev(returns,10),252), range = '0,1,0.1');\r\ngroup2 =  bucket(rank(cap), range = '0,1,0.1');\r\ngroup3 =  bucket(rank(assets), range = '0,1,0.1');\r\ncondition1 = if_else(a-group_mean(a,opt4_total_volume,group1)>0,1,0);\r\nd = 3;\r\nv = vector_neut(log(volume/sharesout),cap);\r\n group_rank(ts_decay_exp_window(ts_mean(condition1,d),20,factor = 0.95),group2)\r\n",
#    'description': None,
#    'operatorCount': 20},
#   'dateCreated': '2024-01-22T23:57:26-05:00',
#   'dateSubmitted': '2024-01-22T23:59:11-05:00',
#   'dateModified': '2024-01-23T04:58:53-05:00',
#   'name': 'option3',
#   'favorite': False,
#   'hidden': False,
#   'color': 'GREEN',
#   'category': 'PRICE_MOMENTUM',
#   'tags': ['Option', 'USA'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 6261072,
#    'bookSize': 20000000,
#    'longCount': 1291,
#    'shortCount': 1161,
#    'turnover': 0.0452,
#    'returns': 0.0627,
#    'drawdown': 0.0477,
#    'margin': 0.002773,
#    'fitness': 1.28,
#    'sharpe': 1.81,
#    'startDate': '2012-01-22',
#    'selfCorrelation': 0.2376,
#    'prodCorrelation': 0.6607,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 1.58,
#      'value': 1.81},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.28},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.0452},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.0452},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.74,
#      'value': 1.64},
#     {'name': 'LOW_AFTER_COST_ILLIQUID_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'afterCostSharpe': 1.7,
#      'limit': 0.89,
#      'value': 0.92},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 0, expected "Unit[]", found "Unit[CSPrice:1]"'},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 1, expected "Unit[]", found "Unit[CSPrice:1,CSShare:1]"'},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2022-01-24',
#      'endDate': '2020-01-25',
#      'limit': 2.37,
#      'value': 2.38}]},
#   'os': {'startDate': '2022-01-23',
#    'osISSharpeRatio': None,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'vdRMZxd',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False,
#    'testPeriod': 'P1Y'},
#   'regular': {'code': " vector_neut(power(rank(group_neutralize(-ts_decay_exp_window(ts_sum(if_else((close/open-1)-group_mean((close/open-1),1,bucket(rank(assets),range = '0,1,0.1'))-0.02>0,1,0)*ts_co_kurtosis(vec_sum(pv27_turnover_d_float),cap,5),3)/3,50),sta1_top3000c10)),2),assets)\r\n",
#    'description': None,
#    'operatorCount': 22},
#   'dateCreated': '2024-01-21T01:46:55-05:00',
#   'dateSubmitted': '2024-01-21T01:49:55-05:00',
#   'dateModified': '2024-01-21T06:50:25-05:00',
#   'name': 'neutass',
#   'favorite': False,
#   'hidden': False,
#   'color': 'RED',
#   'category': 'PRICE_REVERSION',
#   'tags': ['CHN', 'Price volume', 'TOP3000', 'SUBINDUSTRY', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 18049369,
#    'bookSize': 20000000,
#    'longCount': 681,
#    'shortCount': 802,
#    'turnover': 0.3455,
#    'returns': 0.1897,
#    'drawdown': 0.1298,
#    'margin': 0.001098,
#    'fitness': 2.8,
#    'sharpe': 3.78,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.6916,
#    'prodCorrelation': 0.6916,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 3.78},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 2.8},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.3455},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.3455},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.1897},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 2.31,
#      'value': 3.19},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 1.51,
#      'value': 2.18},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0759,
#      'value': 0.1417},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 2.37,
#      'value': 2.43}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.3665,
#    'returns': 0.0005,
#    'drawdown': 0.0569,
#    'margin': 3e-06,
#    'fitness': 0.0,
#    'preCloseSharpe': None,
#    'sharpe': 0.01,
#    'sharpe60': -2.02,
#    'sharpe125': -2.0,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': 0.0,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': {'pnl': 16861524,
#    'bookSize': 20000000,
#    'longCount': 691,
#    'shortCount': 816,
#    'turnover': 0.3446,
#    'returns': 0.1957,
#    'drawdown': 0.1298,
#    'margin': 0.001136,
#    'fitness': 2.97,
#    'sharpe': 3.94,
#    'startDate': '2011-04-07'},
#   'test': {'pnl': 1154706,
#    'bookSize': 20000000,
#    'longCount': 587,
#    'shortCount': 669,
#    'turnover': 0.3541,
#    'returns': 0.1277,
#    'drawdown': 0.0276,
#    'margin': 0.000722,
#    'fitness': 1.41,
#    'sharpe': 2.35,
#    'startDate': '2020-02-13'},
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'Ek5W6O0',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 10,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': " \r\npower(rank(group_neutralize(-ts_decay_exp_window(ts_sum(if_else((close/open-1)-group_mean((close/open-1),1,bucket(rank(assets),range = '0,1,0.1'))-0.01>0,1,0)*ts_co_kurtosis(vec_sum(pv27_turnover_d_float),cap,5),3)/3,50),sta1_top3000c10)),2);\r\n\r\n\r\n",
#    'description': None,
#    'operatorCount': 21},
#   'dateCreated': '2024-01-21T01:41:04-05:00',
#   'dateSubmitted': '2024-01-21T01:42:22-05:00',
#   'dateModified': '2024-01-21T06:50:48-05:00',
#   'name': '0.01',
#   'favorite': False,
#   'hidden': False,
#   'color': 'RED',
#   'category': 'PRICE_REVERSION',
#   'tags': ['Price volume', 'SUBINDUSTRY', 'CHN', 'D1', 'TOP3000'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 17204254,
#    'bookSize': 20000000,
#    'longCount': 630,
#    'shortCount': 738,
#    'turnover': 0.2855,
#    'returns': 0.1808,
#    'drawdown': 0.1532,
#    'margin': 0.001266,
#    'fitness': 2.55,
#    'sharpe': 3.21,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.2985,
#    'prodCorrelation': 0.4533,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 3.21},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 2.55},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.2855},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.2855},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.1808},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.97,
#      'value': 2.82},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 1.28,
#      'value': 2.09},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0723,
#      'value': 0.1381},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 4,
#      'startDate': '2021-02-18',
#      'endDate': '2017-02-19',
#      'limit': 2.37,
#      'value': 2.55}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.2636,
#    'returns': 0.0799,
#    'drawdown': 0.0493,
#    'margin': 0.000606,
#    'fitness': 0.89,
#    'preCloseSharpe': None,
#    'sharpe': 1.62,
#    'sharpe60': -2.44,
#    'sharpe125': -1.01,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': 0.5,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': '0zbam0r',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'e = power(group_rank(-ts_decay_exp_window(ts_sum(if_else(vwap-group_mean(vwap,1,industry)-0.01>0,1,0)*ts_corr((log(volume/sharesout)),cap,5),5),20),sta1_top3000c20),3);\r\ntrade_when(ts_rank(ts_std_dev(returns,10),252)<0.9,e,-1)\r\n',
#    'description': None,
#    'operatorCount': 18},
#   'dateCreated': '2024-01-20T06:08:50-05:00',
#   'dateSubmitted': '2024-01-20T06:09:22-05:00',
#   'dateModified': '2024-01-20T11:09:37-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': None,
#   'tags': ['Price volume', 'TOP3000', 'SUBINDUSTRY', 'CHN', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 10113213,
#    'bookSize': 20000000,
#    'longCount': 1050,
#    'shortCount': 1504,
#    'turnover': 0.244,
#    'returns': 0.1063,
#    'drawdown': 0.1378,
#    'margin': 0.000871,
#    'fitness': 1.85,
#    'sharpe': 2.81,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.4557,
#    'prodCorrelation': 0.6128,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 2.81},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.85},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.244},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.244},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.1063},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.72,
#      'value': 2.92},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 1.12,
#      'value': 1.77},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0425,
#      'value': 0.1177},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 1, expected "Unit[CSPrice:1]", found "Unit[]"'},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 4,
#      'startDate': '2021-02-18',
#      'endDate': '2017-02-19',
#      'limit': 2.37,
#      'value': 2.81}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.2476,
#    'returns': -0.0689,
#    'drawdown': 0.0785,
#    'margin': -0.000556,
#    'fitness': -0.55,
#    'preCloseSharpe': None,
#    'sharpe': -1.05,
#    'sharpe60': -2.3,
#    'sharpe125': -1.79,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.37,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'lrL3802',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': "trade_when(ts_rank(ts_std_dev(returns,10),252)<0.9,-regression_neut(group_neutralize(ts_std_dev(vec_avg(mdl122_betasigma),20)/ ts_mean(vec_avg(mdl122_betasigma),20),bucket(rank(assets),range = '0,1,0.1')),ts_std_dev(returns,30))+group_neutralize(-ts_std_dev(vec_avg(pv27_as_dq_amount)/sharesout,30)/ ts_mean(vec_avg(pv27_as_dq_amount)/sharesout,30),bucket(rank(cap), range = '0,1,0.1')),-1)",
#    'description': None,
#    'operatorCount': 27},
#   'dateCreated': '2024-01-19T06:09:16-05:00',
#   'dateSubmitted': '2024-01-19T06:10:20-05:00',
#   'dateModified': '2024-01-19T11:10:08-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': None,
#   'tags': ['SECTOR', 'Price volume', 'CHN', 'TOP3000', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 11553689,
#    'bookSize': 20000000,
#    'longCount': 962,
#    'shortCount': 675,
#    'turnover': 0.0954,
#    'returns': 0.1214,
#    'drawdown': 0.1483,
#    'margin': 0.002544,
#    'fitness': 2.42,
#    'sharpe': 2.46,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.6096,
#    'prodCorrelation': 0.6249,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 2.46},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 2.42},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.0954},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.0954},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.1214},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.51,
#      'value': 2.21},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.98,
#      'value': 1.39},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0486,
#      'value': 0.0787},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 2.37,
#      'value': 3.91}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.0883,
#    'returns': -0.0586,
#    'drawdown': 0.0815,
#    'margin': -0.001327,
#    'fitness': -0.58,
#    'preCloseSharpe': None,
#    'sharpe': -0.84,
#    'sharpe60': -1.47,
#    'sharpe125': -0.73,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.34,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'mqGnpe1',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 4,
#    'neutralization': 'INDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'i = vec_sum(pv27_sell_volume_small_order);\r\na = ts_corr(close,i,30);\r\nb = vector_neut(a,volume);\r\nc = vector_neut(b,returns);\r\nd = group_backfill(c,industry,3,std = 4.0);\r\nturnover = vec_sum(pv25_d1_turnover);\r\nvtg =  -ts_std_dev(turnover,30);\r\nvt = -ts_std_dev(turnover,30)/ts_mean(turnover,30);\r\nvt2 = group_neutralize(vt,bucket(rank(cap),range = "0.1,1,0.1"));\r\ne = -group_neutralize(d,bucket(rank(cap),range = "0.1,1,0.1"));\r\ntrade_when(ts_rank(ts_std_dev(returns,10),252)<0.7,e+vt,-1)\r\n',
#    'description': None,
#    'operatorCount': 24},
#   'dateCreated': '2024-01-13T02:02:35-05:00',
#   'dateSubmitted': '2024-01-13T02:03:17-05:00',
#   'dateModified': '2024-01-13T02:02:35-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': None,
#   'tags': [],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 7892235,
#    'bookSize': 20000000,
#    'longCount': 1074,
#    'shortCount': 968,
#    'turnover': 0.1395,
#    'returns': 0.0829,
#    'drawdown': 0.1317,
#    'margin': 0.001189,
#    'fitness': 1.71,
#    'sharpe': 2.22,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.6495,
#    'prodCorrelation': 0.6495,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 2.22},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.71},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.1395},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.1395},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.0829},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.36,
#      'value': 2.03},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.89,
#      'value': 1.16},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0332,
#      'value': 0.0689},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 1, expected "Unit[]", found "Unit[CSShare:1]"'},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 2.37,
#      'value': 2.61}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.1457,
#    'returns': -0.013,
#    'drawdown': 0.046,
#    'margin': -0.000179,
#    'fitness': -0.08,
#    'preCloseSharpe': None,
#    'sharpe': -0.28,
#    'sharpe60': -0.86,
#    'sharpe125': 0.67,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.13,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'NndM16p',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'FAST',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'trade_when(ts_rank(ts_std_dev(returns,10),252)<0.9,-regression_neut(group_neutralize(ts_std_dev(vec_sum(mdl122_cvvolp20d),20)/ts_mean(vec_sum(mdl122_cvvolp20d),20),bucket(rank(cap),range = "0.1,1,0.1")),ts_std_dev(returns,20))+group_neutralize(-ts_std_dev(volume/sharesout,30)/ts_mean(volume/sharesout,30),bucket(rank(cap),range = "0.1,1,0.1")),-1) ',
#    'description': None,
#    'operatorCount': 25},
#   'dateCreated': '2024-01-10T23:58:13-05:00',
#   'dateSubmitted': '2024-01-11T00:01:39-05:00',
#   'dateModified': '2024-01-12T04:26:19-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_MOMENTUM',
#   'tags': ['Price volume'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 9352713,
#    'bookSize': 20000000,
#    'longCount': 1504,
#    'shortCount': 1145,
#    'turnover': 0.1697,
#    'returns': 0.0983,
#    'drawdown': 0.1812,
#    'margin': 0.001158,
#    'fitness': 1.99,
#    'sharpe': 2.61,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.6365,
#    'prodCorrelation': 0.6428,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 2.61},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.99},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.1697},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.1697},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.0983},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.6,
#      'value': 2.34},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 1.04,
#      'value': 1.35},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0393,
#      'value': 0.0777},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 2.37,
#      'value': 2.84}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.1767,
#    'returns': -0.0469,
#    'drawdown': 0.0674,
#    'margin': -0.000532,
#    'fitness': -0.45,
#    'preCloseSharpe': None,
#    'sharpe': -0.88,
#    'sharpe60': -2.14,
#    'sharpe125': -0.31,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.34,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'LnvxR31',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'trade_when(ts_rank(ts_std_dev(returns,10),252)<0.9,-regression_neut(group_neutralize(ts_std_dev(vec_sum(mdl122_fc_y2repsg),20)/ts_mean(vec_sum(mdl122_fc_y2repsg),20),bucket(rank(cap),range = "0.1,1,0.1")),ts_std_dev(returns,20))+group_neutralize(-ts_std_dev(volume/sharesout,30)/ts_mean(volume/sharesout,30),bucket(rank(cap),range = "0.1,1,0.1")),-1) ',
#    'description': None,
#    'operatorCount': 25},
#   'dateCreated': '2024-01-10T23:04:18-05:00',
#   'dateSubmitted': '2024-01-10T23:07:22-05:00',
#   'dateModified': '2024-01-12T04:26:50-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_MOMENTUM',
#   'tags': ['Price volume'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 11272227,
#    'bookSize': 20000000,
#    'longCount': 920,
#    'shortCount': 576,
#    'turnover': 0.1298,
#    'returns': 0.1185,
#    'drawdown': 0.2191,
#    'margin': 0.001825,
#    'fitness': 2.01,
#    'sharpe': 2.1,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.5926,
#    'prodCorrelation': 0.6781,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 2.1},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 2.01},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.1298},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.1298},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.1185},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.29,
#      'value': 1.89},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.84,
#      'value': 1.98},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0474,
#      'value': 0.1021},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 4,
#      'startDate': '2021-02-18',
#      'endDate': '2017-02-19',
#      'limit': 2.37,
#      'value': 2.66}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.1336,
#    'returns': -0.035,
#    'drawdown': 0.0553,
#    'margin': -0.000524,
#    'fitness': -0.27,
#    'preCloseSharpe': None,
#    'sharpe': -0.52,
#    'sharpe60': -1.32,
#    'sharpe125': 0.09,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.25,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'jnpQvvj',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 4,
#    'neutralization': 'INDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'a = ts_corr(close,volume,30);\r\nb = vector_neut(a,volume);\r\nc = vector_neut(b,returns);\r\nd = group_backfill(c,industry,3,std = 4.0);\r\nturnover = volume/sharesout;\r\nvtg =  -ts_std_dev(turnover,30);\r\nvt = -ts_std_dev(turnover,30)/ts_mean(turnover,30);\r\nvt2 = group_neutralize(vt,bucket(rank(cap),range = "0.1,1,0.1"));\r\ne = -group_neutralize(d,bucket(rank(cap),range = "0.1,1,0.1"));\r\ntrade_when(ts_rank(ts_std_dev(returns,10),252)<0.7,e+vt,-1)\r\n',
#    'description': None,
#    'operatorCount': 23},
#   'dateCreated': '2024-01-10T22:07:57-05:00',
#   'dateSubmitted': '2024-01-10T22:10:30-05:00',
#   'dateModified': '2024-01-13T01:42:27-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_REVERSION',
#   'tags': ['Price volume', 'CHN', 'INDUSTRY', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 10345762,
#    'bookSize': 20000000,
#    'longCount': 1296,
#    'shortCount': 1314,
#    'turnover': 0.1568,
#    'returns': 0.1087,
#    'drawdown': 0.1896,
#    'margin': 0.001387,
#    'fitness': 2.04,
#    'sharpe': 2.45,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.5996,
#    'prodCorrelation': 0.6956,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 2.45},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 2.04},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.1568},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.1568},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.1087},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.5,
#      'value': 2.58},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.98,
#      'value': 1.66},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0435,
#      'value': 0.0979},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 1, expected "Unit[]", found "Unit[CSShare:1]"'},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 2.37,
#      'value': 2.69}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.152,
#    'returns': -0.0118,
#    'drawdown': 0.0612,
#    'margin': -0.000156,
#    'fitness': -0.06,
#    'preCloseSharpe': None,
#    'sharpe': -0.23,
#    'sharpe60': -1.47,
#    'sharpe125': 0.01,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.09,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'gmNnVWM',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'trade_when(ts_rank(ts_std_dev(returns,10),252)<0.9,-regression_neut(group_neutralize(ts_std_dev(vec_sum(pv27_s_li_initiativebuyamount),20)/ts_mean(vec_sum(pv27_s_li_initiativebuyamount),20),bucket(rank(cap),range = "0.1,1,0.1")),ts_std_dev(returns,20))+group_neutralize(-ts_std_dev(volume/sharesout,30)/ts_mean(volume/sharesout,30),bucket(rank(cap),range = "0.1,1,0.1")),-1) ',
#    'description': None,
#    'operatorCount': 25},
#   'dateCreated': '2024-01-10T08:09:09-05:00',
#   'dateSubmitted': '2024-01-10T12:22:44-05:00',
#   'dateModified': '2024-01-12T04:29:09-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_MOMENTUM',
#   'tags': ['Price volume', 'CHN', 'SECTOR', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 16633798,
#    'bookSize': 20000000,
#    'longCount': 1541,
#    'shortCount': 1095,
#    'turnover': 0.1066,
#    'returns': 0.1748,
#    'drawdown': 0.1025,
#    'margin': 0.003281,
#    'fitness': 3.49,
#    'sharpe': 2.95,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.1615,
#    'prodCorrelation': 0.6596,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 2.07,
#      'value': 2.95},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 3.49},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.1066},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.1066},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.1748},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.81,
#      'value': 2.68},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 1.18,
#      'value': 1.51},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0699,
#      'value': 0.1004},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 2.37,
#      'value': 3.81}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.0997,
#    'returns': -0.0202,
#    'drawdown': 0.0657,
#    'margin': -0.000405,
#    'fitness': -0.14,
#    'preCloseSharpe': None,
#    'sharpe': -0.34,
#    'sharpe60': -3.7,
#    'sharpe125': -0.61,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.12,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'gmLMLxJ',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'ILLIQUID_MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'INDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'ON',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'group_backfill(winsorize(-ts_mean(returns,30)/ts_mean(oth143_sell_tier1_volume,30),std = 4.0), industry, 20, std = 4.0)',
#    'description': None,
#    'operatorCount': 6},
#   'dateCreated': '2023-12-31T04:10:33-05:00',
#   'dateSubmitted': '2023-12-31T21:12:17-05:00',
#   'dateModified': '2024-01-12T04:29:43-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_REVERSION',
#   'tags': ['Price volume', 'USA', 'ILLIQUID_MINVOL1M', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 10635043,
#    'bookSize': 20000000,
#    'longCount': 1289,
#    'shortCount': 1110,
#    'turnover': 0.2781,
#    'returns': 0.116,
#    'drawdown': 0.1129,
#    'margin': 0.000834,
#    'fitness': 1.24,
#    'sharpe': 1.92,
#    'startDate': '2011-04-07',
#    'selfCorrelation': 0.5452,
#    'prodCorrelation': 0.6334,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 1.58,
#      'value': 1.92},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.24},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.2781},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.2781},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.79,
#      'value': 1.31},
#     {'name': 'LOW_AFTER_COST_ILLIQUID_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'afterCostSharpe': 1.29,
#      'limit': 0.68,
#      'value': 1.31},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 0, expected "Unit[]", found "Unit[CSShare:-1]"'},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-16',
#      'endDate': '2019-02-17',
#      'limit': 2.37,
#      'value': 2.94}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.2876,
#    'returns': -0.0024,
#    'drawdown': 0.0846,
#    'margin': -1.7e-05,
#    'fitness': -0.0,
#    'preCloseSharpe': None,
#    'sharpe': -0.03,
#    'sharpe60': 0.7,
#    'sharpe125': 1.61,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.02,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [],
#   'themes': [],
#   'team': None},
#  {'id': 'dnVvwKE',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 9,
#    'neutralization': 'INDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'alpha = ((-1* ((low - close)* (open^5))) / ((low - high)* (close^5)));\r\nhump(alpha,hump = 0.0001)',
#    'description': None,
#    'operatorCount': 9},
#   'dateCreated': '2023-10-07T02:12:43-04:00',
#   'dateSubmitted': '2023-10-07T02:32:51-04:00',
#   'dateModified': '2024-01-12T04:30:17-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_REVERSION',
#   'tags': ['Price volume', 'USA', 'D1', 'INDUSTRY'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 5361541,
#    'bookSize': 20000000,
#    'longCount': 1550,
#    'shortCount': 1558,
#    'turnover': 0.4672,
#    'returns': 0.1099,
#    'drawdown': 0.048,
#    'margin': 0.00047,
#    'fitness': 1.01,
#    'sharpe': 2.08,
#    'startDate': '2016-03-11',
#    'selfCorrelation': 0.745,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 1.58,
#      'value': 2.08},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.01},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.4672},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.4672},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.9,
#      'value': 1.51},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 0, expected "Unit[]", found "Unit[CSPrice:1]"'},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 0, expected "Unit[]", found "Unit[CSPrice:1]"'},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-16',
#      'endDate': '2019-02-17',
#      'limit': 2.37,
#      'value': 3.36}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.4717,
#    'returns': -0.0118,
#    'drawdown': 0.0539,
#    'margin': -5e-05,
#    'fitness': -0.02,
#    'preCloseSharpe': None,
#    'sharpe': -0.12,
#    'sharpe60': -0.06,
#    'sharpe125': -0.33,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -0.06,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None},
#  {'id': 'KndZ0mg',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 10,
#    'neutralization': 'MARKET',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'alpha = (0 - (1* ((close - vwap) / TS_decay_linear(rank(ts_arg_max(close, 30)), 2))));\r\n#winsorize(alpha,std=3.2)\r\nwinsorize(hump(alpha,hump = 0.00008),std=2.5)\r\n',
#    'description': None,
#    'operatorCount': 9},
#   'dateCreated': '2023-10-07T02:00:13-04:00',
#   'dateSubmitted': '2023-10-07T02:01:09-04:00',
#   'dateModified': '2024-01-12T04:31:23-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_REVERSION',
#   'tags': ['USA', 'MARKET', 'D1', 'Price volume'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 9165345,
#    'bookSize': 20000000,
#    'longCount': 2004,
#    'shortCount': 1108,
#    'turnover': 0.4443,
#    'returns': 0.1878,
#    'drawdown': 0.0852,
#    'margin': 0.000845,
#    'fitness': 1.22,
#    'sharpe': 1.88,
#    'startDate': '2016-03-11',
#    'selfCorrelation': 0.554,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 1.58,
#      'value': 1.88},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.22},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.4443},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.4443},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.81,
#      'value': 1.35},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 1, expected "Unit[]", found "Unit[CSPrice:1]"'},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-16',
#      'endDate': '2019-02-17',
#      'limit': 2.37,
#      'value': 2.64}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.4688,
#    'returns': 0.0575,
#    'drawdown': 0.1407,
#    'margin': 0.000245,
#    'fitness': 0.15,
#    'preCloseSharpe': None,
#    'sharpe': 0.44,
#    'sharpe60': 2.66,
#    'sharpe125': 0.3,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': 0.23,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None},
#  {'id': 'knrPp3O',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 4,
#    'neutralization': 'MARKET',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'alpha = zscore((-1*((LOW-CLOSE)*(OPEN^5)))/((CLOSE-HIGH)*(CLOSE^5)));\r\n#winsorize(alpha,std=4.3)\r\n#winsorize(hump(alpha,hump=0.0001),std=4.3)\r\nhump(alpha,hump=0.0001)',
#    'description': None,
#    'operatorCount': 10},
#   'dateCreated': '2023-10-06T04:16:20-04:00',
#   'dateSubmitted': '2023-10-06T05:04:15-04:00',
#   'dateModified': '2024-01-12T04:32:02-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_REVERSION',
#   'tags': ['USA', 'D1', 'Price volume', 'MARKET'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 7482321,
#    'bookSize': 20000000,
#    'longCount': 2223,
#    'shortCount': 836,
#    'turnover': 0.6272,
#    'returns': 0.1533,
#    'drawdown': 0.0752,
#    'margin': 0.000489,
#    'fitness': 1.02,
#    'sharpe': 2.07,
#    'startDate': '2016-03-11',
#    'selfCorrelation': 0.5706,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 1.58,
#      'value': 2.07},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.02},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.6272},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.6272},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.9,
#      'value': 1.65},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 0, expected "Unit[]", found "Unit[CSPrice:1]"'},
#     {'name': 'UNITS',
#      'result': 'WARNING',
#      'message': 'Incompatible unit for input at index 0, expected "Unit[]", found "Unit[CSPrice:1]"'},
# ...
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None},
#  {'id': 'EgdbQ6R',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 25,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.04,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': '-rank(ts_sum((close-low)/(high-close),4))*rank(ts_delta(close,5))',
#    'description': None,
#    'operatorCount': 9},
#   'dateCreated': '2023-09-20T08:37:57-04:00',
#   'dateSubmitted': '2023-09-21T08:12:42-04:00',
#   'dateModified': '2024-01-12T07:14:13-05:00',
#   'name': 'Better',
#   'favorite': False,
#   'hidden': False,
#   'color': 'RED',
#   'category': 'PRICE_REVERSION',
#   'tags': ['Price volume', 'SUBINDUSTRY', 'USA', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 15825737,
#    'bookSize': 20000000,
#    'longCount': 104,
#    'shortCount': 96,
#    'turnover': 0.1917,
#    'returns': 0.3243,
#    'drawdown': 0.2027,
#    'margin': 0.003384,
#    'fitness': 2.54,
#    'sharpe': 1.95,
#    'startDate': '2016-03-11',
#    'selfCorrelation': 0.0241,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'PASS',
#      'limit': 1.58,
#      'value': 1.95},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 2.54},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.1917},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.1917},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.84,
#      'value': 1.44},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-16',
#      'endDate': '2019-02-17',
#      'limit': 2.02,
#      'value': 2.76}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.2047,
#    'returns': 0.0055,
#    'drawdown': 0.2636,
#    'margin': 5.4e-05,
#    'fitness': 0.0,
#    'preCloseSharpe': None,
#    'sharpe': 0.03,
#    'sharpe60': 1.26,
#    'sharpe125': 0.42,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': 0.02,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None},
#  {'id': 'k1AeW7k',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 0,
#    'decay': 3,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.08,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'alpha = -ts_corr(ts_rank(volume,10), ts_rank(vwap,10),20);\r\nif_else(rank(alpha)>0.6 || rank(alpha)<0.4, alpha, -0.6)\r\n',
#    'description': None,
#    'operatorCount': 10},
#   'dateCreated': '2023-09-20T06:32:17-04:00',
#   'dateSubmitted': '2023-09-20T06:32:41-04:00',
#   'dateModified': '2024-01-12T07:14:32-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'PRICE_REVERSION',
#   'tags': ['Price volume', 'SUBINDUSTRY', 'USA', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 7951922,
#    'bookSize': 20000000,
#    'longCount': 1197,
#    'shortCount': 1702,
#    'turnover': 0.1946,
#    'returns': 0.1683,
#    'drawdown': 0.0505,
#    'margin': 0.00173,
#    'fitness': 2.53,
#    'sharpe': 2.72,
#    'startDate': '2016-03-11',
#    'selfCorrelation': -0.0492,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'FAIL',
#      'limit': 3.49,
#      'value': 2.72},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.5, 'value': 2.53},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.1946},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.1946},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.12, 'value': 0.1683},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.67,
#      'value': 3.03},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 1.09,
#      'value': 1.18},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0673,
#      'value': 0.0692},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'FAIL',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 3.49,
#      'value': 1.73}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.1775,
#    'returns': 0.0181,
#    'drawdown': 0.0458,
#    'margin': 0.000204,
#    'fitness': 0.07,
#    'preCloseSharpe': None,
#    'sharpe': 0.23,
#    'sharpe60': -0.68,
#    'sharpe125': -0.46,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': 0.08,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None},
#  {'id': 'aApXVv2',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'CHN',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'rank(ts_delta(retained_earnings/sharesout,75))',
#    'description': None,
#    'operatorCount': 3},
#   'dateCreated': '2023-09-20T06:27:31-04:00',
#   'dateSubmitted': '2023-09-20T06:32:02-04:00',
#   'dateModified': '2024-01-12T07:14:49-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'FUNDAMENTAL',
#   'tags': ['Fundamental', 'SUBINDUSTRY', 'USA', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 4645718,
#    'bookSize': 20000000,
#    'longCount': 1035,
#    'shortCount': 1052,
#    'turnover': 0.0826,
#    'returns': 0.0983,
#    'drawdown': 0.111,
#    'margin': 0.002381,
#    'fitness': 1.65,
#    'sharpe': 1.86,
#    'startDate': '2016-03-11',
#    'selfCorrelation': 0.0,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'FAIL',
#      'limit': 2.07,
#      'value': 1.86},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.65},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.0826},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.0826},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_RETURNS', 'result': 'PASS', 'limit': 0.08, 'value': 0.0983},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 1.14,
#      'value': 2.29},
#     {'name': 'LOW_ROBUST_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.74,
#      'value': 1.12},
#     {'name': 'LOW_ROBUST_UNIVERSE_RETURNS',
#      'result': 'PASS',
#      'ratio': 0.4,
#      'limit': 0.0393,
#      'value': 0.0488},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-18',
#      'endDate': '2019-02-19',
#      'limit': 2.07,
#      'value': 2.48}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.0797,
#    'returns': -0.152,
#    'drawdown': 0.1395,
#    'margin': -0.003814,
#    'fitness': -2.29,
#    'preCloseSharpe': None,
#    'sharpe': -2.08,
#    'sharpe60': -2.74,
#    'sharpe125': -2.2,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -1.12,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None},
#  {'id': 'k1wlPkk',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'ts_av_diff(mdf_nps,500)',
#    'description': None,
#    'operatorCount': 1},
#   'dateCreated': '2023-09-18T06:21:10-04:00',
#   'dateSubmitted': '2023-09-18T06:25:36-04:00',
#   'dateModified': '2024-01-12T07:15:20-05:00',
#   'name': 'can submit 1.48',
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'FUNDAMENTAL',
#   'tags': ['Fundamental', 'SUBINDUSTRY', 'USA', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 6466439,
#    'bookSize': 20000000,
#    'longCount': 1254,
#    'shortCount': 1361,
#    'turnover': 0.0201,
#    'returns': 0.1325,
#    'drawdown': 0.1326,
#    'margin': 0.013157,
#    'fitness': 1.48,
#    'sharpe': 1.44,
#    'startDate': '2016-03-11',
#    'selfCorrelation': 0.308,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'FAIL',
#      'limit': 1.58,
#      'value': 1.44},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.48},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.0201},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.0201},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.62,
#      'value': 0.62},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'FAIL',
#      'year': 3,
#      'startDate': '2021-02-16',
#      'endDate': '2018-02-17',
#      'limit': 1.58,
#      'value': 1.32}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.0228,
#    'returns': -0.2616,
#    'drawdown': 0.2596,
#    'margin': -0.022906,
#    'fitness': -3.25,
#    'preCloseSharpe': None,
#    'sharpe': -2.25,
#    'sharpe60': -3.19,
#    'sharpe125': -2.29,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -1.56,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None},
#  {'id': '1a8ELmQ',
#   'type': 'REGULAR',
#   'author': 'WD77850',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'USA',
#    'universe': 'TOP3000',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'SUBINDUSTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': {'code': 'rank(mdf_rds)',
#    'description': None,
#    'operatorCount': 1},
#   'dateCreated': '2023-09-18T06:04:52-04:00',
#   'dateSubmitted': '2023-09-18T06:12:19-04:00',
#   'dateModified': '2024-01-12T07:15:33-05:00',
#   'name': None,
#   'favorite': False,
#   'hidden': False,
#   'color': None,
#   'category': 'FUNDAMENTAL',
#   'tags': ['Fundamental', 'SUBINDUSTRY', 'USA', 'D1'],
#   'grade': None,
#   'stage': 'OS',
#   'status': 'ACTIVE',
#   'is': {'pnl': 6432918,
#    'bookSize': 20000000,
#    'longCount': 399,
#    'shortCount': 354,
#    'turnover': 0.0118,
#    'returns': 0.1318,
#    'drawdown': 0.1133,
#    'margin': 0.022314,
#    'fitness': 1.44,
#    'sharpe': 1.4,
#    'startDate': '2016-03-11',
#    'selfCorrelation': 0.0,
#    'prodCorrelation': 0.0,
#    'checks': [{'name': 'LOW_SHARPE',
#      'result': 'FAIL',
#      'limit': 1.58,
#      'value': 1.4},
#     {'name': 'LOW_FITNESS', 'result': 'PASS', 'limit': 1.0, 'value': 1.44},
#     {'name': 'LOW_TURNOVER', 'result': 'PASS', 'limit': 0.01, 'value': 0.0118},
#     {'name': 'HIGH_TURNOVER', 'result': 'PASS', 'limit': 0.7, 'value': 0.0118},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PASS'},
#     {'name': 'LOW_SUB_UNIVERSE_SHARPE',
#      'result': 'PASS',
#      'limit': 0.61,
#      'value': 1.86},
#     {'name': 'IS_LADDER_SHARPE',
#      'result': 'PASS',
#      'year': 2,
#      'startDate': '2021-02-16',
#      'endDate': '2019-02-17',
#      'limit': 2.02,
#      'value': 2.1}]},
#   'os': {'startDate': '2021-02-14',
#    'turnover': 0.0129,
#    'returns': -0.4022,
#    'drawdown': 0.3864,
#    'margin': -0.06214,
#    'fitness': -4.2,
#    'preCloseSharpe': None,
#    'sharpe': -2.34,
#    'sharpe60': -3.68,
#    'sharpe125': -1.74,
#    'sharpe250': None,
#    'sharpe500': None,
#    'osISSharpeRatio': -1.67,
#    'preCloseSharpeRatio': None,
#    'checks': [{'name': 'PROD_CORRELATION', 'result': 'PENDING'},
#     {'name': 'CONCENTRATED_WEIGHT', 'result': 'PENDING'},
#     {'name': 'NEW_HIGH', 'result': 'PENDING'},
#     {'name': 'SUB_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'IS_SHARPE', 'result': 'PENDING'},
#     {'name': 'DRAWDOWN', 'result': 'PENDING'},
#     {'name': 'SUPER_UNIVERSE_SHARPE', 'result': 'PENDING'},
#     {'name': 'RANK_SHARPE', 'result': 'PENDING'},
#     {'name': 'MEMORY_USAGE', 'result': 'PENDING'},
#     {'name': 'SHARPE', 'result': 'PENDING'},
#     {'name': 'SELF_CORRELATION', 'result': 'PENDING'}]},
#   'train': None,
#   'test': None,
#   'prod': None,
#   'competitions': [{'id': 'challenge', 'name': 'Challenge'},
#    {'id': 'cuhkszalphathoncn2023', 'name': 'CUHKsz - Alphathon 2023'}],
#   'themes': [],
#   'team': None}]

# %% [markdown]
# 取得新alpha 的before or after

# %% [markdown]
# 拿到旧alpha的Pnl

# %%
from time import sleep

def pnl_search(alpha_id):
    finished = False
    while True:
        pnl  = s.get("https://api.worldquantbrain.com/alphas/"+ alpha_id+"/recordsets/pnl")
        if pnl.headers.get("Retry-After", 0) == 0:
            break
        print("Sleeping for " + pnl.headers["Retry-After"] + " seconds")
        sleep(float(pnl.headers["Retry-After"]))
    print("PnL retrieved")
    pnla = pnl.json()
    return pnla

# %%
import numpy as np

def corr_count(list1, list2):
    # 移除包含 NoneType 的元素
    valid_indices = [i for i in range(len(list1)) if list1[i] is not None and list2[i] is not None]
    list1_valid = [list1[i] for i in valid_indices]
    list2_valid = [list2[i] for i in valid_indices]
    
    # 使用numpy.corrcoef计算相关性
    correlation_matrix = np.corrcoef(list1_valid, list2_valid)
    
    # 获取相关性矩阵中的相关系数
    correlation_coefficient = correlation_matrix[0, 1]
    
    return correlation_coefficient

# %%
def sameLen(list1,list2):
    min_length = min(len(list1), len(list2))
    list1 = list1[-min_length:]
    list2 = list2[-min_length:]
    return list1,list2

# %%
list_corr = []
for i in sim_result:
    ida = i["id"]
    pnlA = pnl_search(ida) #这个返回值不知道是不是这样
    pnl_list = []
    records = pnlA["records"]#这是一个大列表 现在要取到所有小列表的索引1
    for lis in records:
        pnl_list.append(lis[1])
    n_pnl_list,n_new = sameLen(pnl_list,before)#这里改before 和after
    list_corr.append(corr_count(n_pnl_list,n_new))#这里改before 和after
# Out:
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# Sleeping for 1.0 seconds
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# Sleeping for 1.0 seconds
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved

# %%
list_corr
# Out:
# [-0.05010830277867126,
#  -0.1191408433633155,
#  -0.08555367767845959,
#  -0.04278390046449597,
#  -0.02687469090068781,
#  0.010091838950315339,
#  0.04300318218120984,
#  -0.08528828203225713,
#  0.06674403351121831,
#  -0.08931243242144477,
#  0.02629175033560336,
#  0.6497510732401421,
#  0.584061910980717,
#  0.5965971059769869,
#  0.6708825798563182,
#  0.6095433786363441,
#  0.48276856389826195,
#  0.4833246073662789,
#  0.5148050352459218,
#  0.5947912171597416,
#  0.6595277389007791,
#  0.6558079110505914,
#  0.5632250310302275,
#  0.6120998325222918,
#  0.5366850950997158,
#  0.5176694565355578,
#  0.5138664558380867,
#  0.5591406566448897,
#  0.5558558113590272,
#  0.6527844310111521,
#  0.44164111264581185,
#  0.6820684713330091,
#  0.6236612728416224,
#  0.7075778518157947,
#  0.6347507670699614,
#  0.7083755032554767,
#  0.6023390874561724,
#  0.5448585746612413,
#  0.4425717126583612,
#  0.7440881752898111,
#  0.7633007688588122,
#  0.5561808456113715,
#  0.30745278792077785,
#  0.5645786827985507,
#  0.322357703513078,
#  0.5856178336635972]

# %% [markdown]
# 最大相关系数值

# %%
# 最大值
max_value = max(list_corr)
print(f"最大值：{max_value}")

# 最小值
min_value = min(list_corr)
print(f"最小值：{min_value}")

# 平均值
average_value = sum(list_corr) / len(list_corr)
print(f"平均值：{average_value}")
# Out:
# 最大值：0.7633007688588122
# 最小值：-0.1191408433633155
# 平均值：0.4324277765018586

# %% [markdown]
# 滚动窗口的方法

# %%
import pandas as pd

import pandas as pd

def calculate_rolling_correlation(list1, list2, window_size):
    df = pd.DataFrame({'list1': list1, 'list2': list2})
    rolling_correlation_results = df.rolling(window=window_size).corr()
    correlation_main = rolling_correlation_results.loc[:, ('list1', 'list2')]
    return correlation_main

# %%
list_corr = []

for i in sim_result:
    ida = i["id"]                                                                                                                                                                                                                                                                                        
    pnlA = pnl_search(ida)
    pnl_list = []

    # 获取 pnl_list，这部分保持不变
    for lis in pnlA["records"]:
        pnl_list.append(lis[1])

    n_pnl_list, n_new = sameLen(pnl_list, before)

    # 计算滚动窗口相关性
    correlation_main = calculate_rolling_correlation(n_pnl_list, n_new, 400)

    specific_column_correlation = correlation_main['list1']
    list_corr.append(specific_column_correlation)
# Out:
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrieved
# PnL retrie
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.340372
#  1454  list1    1.000000
#        list2    0.325988
#  1455  list1    1.000000
#        list2    0.311060
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.533625
#  1454  list1    1.000000
#        list2    0.523669
#  1455  list1    1.000000
#        list2    0.513127
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.001790
#  1454  list1    1.000000
#        list2   -0.011778
#  1455  list1    1.000000
#        list2   -0.026263
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.678872
#  1454  list1    1.000000
#        list2    0.681225
#  1455  list1    1.000000
#        list2    0.683342
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.482759
#  1454  list1    1.000000
#        list2    0.477882
#  1455  list1    1.000000
#        list2    0.473765
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.580153
#  1454  list1    1.000000
#        list2    0.574906
#  1455  list1    1.000000
#        list2    0.569708
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.613162
#  1454  list1    1.000000
#        list2    0.616220
#  1455  list1    1.000000
#        list2    0.618922
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.632355
#  1454  list1    1.000000
#        list2    0.633532
#  1455  list1    1.000000
#        list2    0.634456
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.630682
#  1454  list1    1.000000
#        list2    0.633557
#  1455  list1    1.000000
#        list2    0.636057
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.544070
#  1454  list1    1.000000
#        list2    0.546110
#  1455  list1    1.000000
#        list2    0.548115
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.170982
#  1454  list1    1.000000
#        list2    0.181961
#  1455  list1    1.000000
#        list2    0.193472
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.650412
#  1454  list1    1.000000
#        list2    0.651939
#  1455  list1    1.000000
#        list2    0.653449
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.600863
#  1454  list1    1.000000
#        list2    0.603634
#  1455  list1    1.000000
#        list2    0.606386
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.560380
#  1454  list1    1.000000
#        list2    0.554682
#  1455  list1    1.000000
#        list2    0.549293
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1405  list2    0.495604
#  1406  list1    1.000000
#        list2    0.486883
#  1407  list1    1.000000
#        list2    0.477454
#  Name: list1, Length: 2816, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1405  list2    0.615708
#  1406  list1    1.000000
#        list2    0.615324
#  1407  list1    1.000000
#        list2    0.614195
#  Name: list1, Length: 2816, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2   -0.140288
#  1454  list1    1.000000
#        list2   -0.124842
#  1455  list1    1.000000
#        list2   -0.108955
#  Name: list1, Length: 2912, dtype: float64,
#  0     list1         NaN
#        list2         NaN
#  1     list1         NaN
#        list2         NaN
#  2     list1         NaN
#                   ...
#  1453  list2    0.631954
#  1454  list1    1.000000
#        list2    0.635198
#  1455  list1    1.000000
#        list2    0.638554
#  Name: list1, Length: 2912, dtype: float64]

# %% [markdown]
# 方案2

# %%
import pandas as pd

def calculate_rolling_correlation(list1, list2, window_size):
    # 创建 DataFrame，同时处理可能存在的空值
    df = pd.DataFrame({'list1': list1, 'list2': list2})
    df = df.dropna()  # 去除包含空值的行
    rolling_correlation_results = df.rolling(window=window_size).corr()
    
    # 选择 'list2' 列的相关性
    correlation_main = rolling_correlation_results.xs('list2', level=1)
    
    return correlation_main

list_corr = []

for i in sim_result:
    ida = i["id"]
    pnlA = pnl_search(ida)
    pnl_list = []

    # 获取 pnl_list，这部分保持不变
    for lis in pnlA["records"]:
        pnl_list.append(lis[1])

    n_pnl_list, n_new = sameLen(pnl_list, before)

    # 计算滚动窗口相关性
    correlation_main = calculate_rolling_correlation(n_pnl_list, n_new, 400)

    # 获取 'list2' 列的最大值并添加到列表
    max_value_list2 = correlation_main.mean().iloc[0]  # 选择第一个值
    list_corr.append(max_value_list2)
# Out:
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# Sleeping for 1.0 seconds
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved
# Sleeping for 1.0 seconds
# PnL retrieved

# %%
list_corr
# Out:
# [0.09664396563781188,
#  0.1209167518476167,
#  0.11670968764331839,
#  0.3118378730176808,
#  0.19590961607966395,
#  0.3369813517261103,
#  0.4128881308965916,
#  0.2985720845818595,
#  0.32423563067015415,
#  0.1428607861555794,
#  0.1117838246069347,
#  0.11709386464363657,
#  0.25650106546766926,
#  0.18909406211421617,
#  0.123827076198024,
#  0.5178819588140761,
#  0.10343833467034287,
#  0.06508931668254275,
#  0.1714380710308014,
#  0.37192349471810326,
#  0.39343423866889704,
#  0.13772514009170939,
#  0.11109725000046751,
#  0.3952166403782023,
#  0.3542029607755554,
#  0.28665296903107707,
#  0.05819935756614167,
#  0.21623087775138067,
#  -0.16430157393891057,
#  0.22038208253430416,
#  0.16513661868229146,
#  0.28642694444414446,
#  0.06479791017397071,
#  0.48296196452427764,
#  0.1290546737325264,
#  0.29348854668107727,
#  0.3563467458889437,
#  0.10160202229308161,
#  0.13824269730733266,
#  0.6654833084807836,
#  0.6978856889022109,
#  0.2333042995351409,
#  0.18697628416691353,
#  0.5392032447062828,
#  0.24701665233008005,
#  0.2933682857720896]

# %%
# 最大值
max_value = max(list_corr)
print(f"最大值：{max_value}")

# 最小值
min_value = min(list_corr)
print(f"最小值：{min_value}")

# 平均值
average_value = sum(list_corr) / len(list_corr)
print(f"平均值：{average_value}")
# Out:
# 最大值：0.6978856889022109
# 最小值：-0.16430157393891057
# 平均值：0.24512527777571097

# %%
final_score_b =calculate_score(before_after_yearlyStats['before'],returns1,turnover1)

# %%
final_score_a = calculate_score(before_after_yearlyStats['after'],returns2,turnover2)*max_value

# %% [markdown]
# 待完善

# %%
score_rank =  calculate_score(before_after_yearlyStats['after'],returns2,turnover2)*max_value

# %%
score_sign  =  calculate_score(before_after_yearlyStats['after'],returns2,turnover2)*max_value

# %%
def update_alpha_color(session, alpha_id,color,final_score_a,final_score_b):
    update_data = {"color":color}
    response = session.patch(f"https://api.worldquantbrain.com/alphas/{alpha_id}", json=update_data)
    return response.status_code == 200
if final_score_a>final_score_b*0.8:
    update_alpha_color(session = s, alpha_id = alpha_id, color = 'GREEN',final_score_a = final_score_a,final_score_b = final_score_b)
else:
    print("The alpha is not avery good")
    update_alpha_color(session = s, alpha_id = alpha_id, color = 'RED',final_score_a = final_score_a,final_score_b = final_score_b)
# Out:
# The alpha is not avery good

# %% [markdown]
# New SCORE

# %%
def update_alpha_color(session, alpha_id,color,final_score_a,final_score_b,score_rank,socre_sign):
    update_data = {"color":color}
    response = session.patch(f"https://api.worldquantbrain.com/alphas/{alpha_id}", json=update_data)
    return response.status_code == 200
if (final_score_a*0.6+score_rank*0.2+score_sign*0.2)>final_score_b*0.8:
    update_alpha_color(session = s, alpha_id = alpha_id, color = 'GREEN',final_score_a = final_score_a,final_score_b = final_score_b)
else:
    print("The alpha is not avery good")
    update_alpha_color(session = s, alpha_id = alpha_id, color = 'RED',final_score_a = final_score_a,final_score_b = final_score_b)
